# %%
import pandas as pd

# %%
#it is used for read the csv file 
df = pd.read_csv("Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
#unique function is used for take the unique data from given a column 
df['bike_name'].unique()
# Out:
# array(['TVS Star City Plus Dual Tone 110cc',
#        'Royal Enfield Classic 350cc', 'Triumph Daytona 675R',
#        'TVS Apache RTR 180cc', 'Yamaha FZ S V 2.0 150cc-Ltd. Edition',
#        'Yamaha FZs 150cc', 'Honda CB Hornet 160R  ABS DLX',
#        'Hero Splendor Plus Self Alloy 100cc',
#        'Royal Enfield Thunderbird X 350cc',
#        'Royal Enfield Classic Desert Storm 500cc',
#        'Yamaha YZF-R15 2.0 150cc', 'Yamaha FZ25 250cc',
#        'Bajaj Pulsar NS200', 'Bajaj Discover 100M', 'Bajaj Discover 125M',
#        'Bajaj Pulsar NS200 ABS', 'Bajaj Pulsar RS200 ABS',
#        'Suzuki Gixxer SF 150cc', 'Benelli 302R 300CC',
#        'Hero Splendor iSmart Plus IBS 110cc',
#        'Royal Enfield Classic Chrome 500cc', 'Yamaha FZ V 2.0 150cc',
#        'Hero Super Splendor 125cc', 'Honda CBF Stunner 125cc',
#        'Bajaj Pulsar 150cc', 'Honda X-Blade 160CC ABS',
#        'Bajaj Avenger 220cc', 'KTM RC 390cc', 'Honda CB Unicorn 150cc',
# ...

# %%
#it i9s used for count the unique in  brand column
df['brand'].nunique()
# Out:
# 23

# %%
df['owner'].nunique()
# Out:
# 4

# %%
# head is used for take the row according to given a nu,mber of row in head function 
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
#total brand ki unique brand
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
#dublicati ke liye function name is
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
#duplicated function is ussed for take  the duplicate data
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
#it is used for drop the duplicated data
df.drop_duplicates(inplace=True)

# %%
#it is used for calculate the duplicate data 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.tail()
# Out:
#                            bike_name     price       city  kms_driven  \
# 9362       Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369             Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370  Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371           Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372        Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# 9362  First Owner  8.0  150.0             Hero
# 9369  First Owner  9.0  220.0            Bajaj
# 9370  First Owner  4.0  750.0  Harley-Davidson
# 9371  First Owner  4.0  400.0            Bajaj
# 9372  First Owner  5.0  220.0            Bajaj

# %%
#null ke liye
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
#null value mko drop karne ke liye
df.dropna(inplace=True)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
#single column drop karna hai
#df.drop('city',axis=1,inplace=True)

# %%
df.drop(['bike_name'] , axis=1, inplace=True)

# %%
char =df.select_dtypes(include='object')
num =df.select_dtypes(exclude='object')

# %%
char
# Out:
#            city        owner            brand
# 0     Ahmedabad  First Owner              TVS
# 1         Delhi  First Owner    Royal Enfield
# 2         Delhi  First Owner          Triumph
# 3     Bangalore  First Owner              TVS
# 4     Bangalore  First Owner           Yamaha
# ...         ...          ...              ...
# 9362      Delhi  First Owner             Hero
# 9369  Bangalore  First Owner            Bajaj
# 9370    Jodhpur  First Owner  Harley-Davidson
# 9371  Hyderabad  First Owner            Bajaj
# 9372  Hyderabad  First Owner            Bajaj
#
# [7324 rows x 3 columns]

# %%
num
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
char
# Out:
#            city        owner            brand
# 0     Ahmedabad  First Owner              TVS
# 1         Delhi  First Owner    Royal Enfield
# 2         Delhi  First Owner          Triumph
# 3     Bangalore  First Owner              TVS
# 4     Bangalore  First Owner           Yamaha
# ...         ...          ...              ...
# 9362      Delhi  First Owner             Hero
# 9369  Bangalore  First Owner            Bajaj
# 9370    Jodhpur  First Owner  Harley-Davidson
# 9371  Hyderabad  First Owner            Bajaj
# 9372  Hyderabad  First Owner            Bajaj
#
# [7324 rows x 3 columns]

# %%
# owner_dict={'First owner':1,'Second  owner':2,'Third owner':3,'Fourth owner or more':4}
# char['owner']=char['owner'].map(owner_dict)

# %%
char
# Out:
#            city        owner            brand
# 0     Ahmedabad  First Owner              TVS
# 1         Delhi  First Owner    Royal Enfield
# 2         Delhi  First Owner          Triumph
# 3     Bangalore  First Owner              TVS
# 4     Bangalore  First Owner           Yamaha
# ...         ...          ...              ...
# 9362      Delhi  First Owner             Hero
# 9369  Bangalore  First Owner            Bajaj
# 9370    Jodhpur  First Owner  Harley-Davidson
# 9371  Hyderabad  First Owner            Bajaj
# 9372  Hyderabad  First Owner            Bajaj
#
# [7324 rows x 3 columns]

# %%
char['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
brand_dict={'First Owner':1, 'Second Owner':2, 'Third Owner':3, 'Fourth Owner Or More':4}
char['owner']=char['owner'].map(brand_dict)

# %%
char
# Out:
#            city  owner            brand
# 0     Ahmedabad      1              TVS
# 1         Delhi      1    Royal Enfield
# 2         Delhi      1          Triumph
# 3     Bangalore      1              TVS
# 4     Bangalore      1           Yamaha
# ...         ...    ...              ...
# 9362      Delhi      1             Hero
# 9369  Bangalore      1            Bajaj
# 9370    Jodhpur      1  Harley-Davidson
# 9371  Hyderabad      1            Bajaj
# 9372  Hyderabad      1            Bajaj
#
# [7324 rows x 3 columns]

# %%
char['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
brand_dict={'TVS':1,   'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
                'Honda':5,          'Hero':6,           'Bajaj':7,          'Suzuki':8,
                'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
                'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
                'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
                'Yezdi':21,              'MV':22,           'Ideal':23}

# %%
char['brand']=char['brand'].map(brand_dict)
char
# Out:
#            city  owner  brand
# 0     Ahmedabad      1      1
# 1         Delhi      1      2
# 2         Delhi      1      3
# 3     Bangalore      1      1
# 4     Bangalore      1      4
# ...         ...    ...    ...
# 9362      Delhi      1      6
# 9369  Bangalore      1      7
# 9370    Jodhpur      1     15
# 9371  Hyderabad      1      7
# 9372  Hyderabad      1      7
#
# [7324 rows x 3 columns]

# %%
char['city'].unique()
# Out:
# array(['Ahmedabad', 'Delhi', 'Bangalore', 'Mumbai', 'Kalyan', 'Faridabad',
#        'Mettur', 'Hyderabad', 'Kaithal', 'Gurgaon', 'Pune', 'Noida',
#        'Nashik', 'Kochi', 'Allahabad', 'Samastipur', 'Nadiad', 'Lucknow',
#        'Jaipur', 'Karnal', 'Gorakhpur', 'Vidisha', 'Hosur', 'Bagalkot',
#        'Baripara', 'Agra', 'Dharwad', 'Vadodara', 'Jalandhar', 'Surat',
#        'Chennai', 'Navi Mumbai', 'Gandhidham', 'Visakhapatnam',
#        'Thrissur', 'Kolkata', 'Ernakulam', 'Barasat', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Bhopal', 'Hamirpur(hp)', 'Kottayam',
#        'Arrah', 'Patiala', 'Ranga Reddy', 'Mandi', 'Ludhiana', 'Mandya',
#        'Siliguri', 'Aurangabad', 'Kanpur', 'Bhilwara', 'Meerut', 'Rewari',
#        'Ahmednagar', 'Wardha', 'Chandigarh', 'Ranchi', 'Panvel', 'Thane',
#        'Jabalpur', 'Kota', 'Rohtak', 'Rajkot', 'Varanasi', '24 Pargana',
#        'Banka', 'Nagpur', 'Banki', 'Pali', 'Chhatarpur', 'Katihar',
# ...

# %%
city_dict={'Ahmedabad':1,        'Delhi':2,    'Bangalore':3,       'Mumbai':4,
            'Kalyan':5,    'Faridabad':6,       'Mettur':7,    'Hyderabad':8,
            'Kaithal':9,      'Gurgaon':10,      'Bhubaneswar':11,      'Raiganj':12, 
            'Bhilai Nagar':13,       'Baloda':14, 'Anantnag':15,   'Berhampore':16,      
            'Silvasa':17,       'Hospet':18,        'Palai':19,        'Sidhi':20}
char['city']=char['city'].map(city_dict)

# %%
char
# Out:
#       city  owner  brand
# 0      1.0      1      1
# 1      2.0      1      2
# 2      2.0      1      3
# 3      3.0      1      1
# 4      3.0      1      4
# ...    ...    ...    ...
# 9362   2.0      1      6
# 9369   3.0      1      7
# 9370   NaN      1     15
# 9371   8.0      1      7
# 9372   8.0      1      7
#
# [7324 rows x 3 columns]

# %%
total_df=pd.concat([char,num], axis=1)#es me char or num data frame

# %%
total_df
# Out:
#       city  owner  brand     price  kms_driven  age  power
# 0      1.0      1      1   35000.0     17654.0  3.0  110.0
# 1      2.0      1      2  119900.0     11000.0  4.0  350.0
# 2      2.0      1      3  600000.0       110.0  8.0  675.0
# 3      3.0      1      1   65000.0     16329.0  4.0  180.0
# 4      3.0      1      4   80000.0     10000.0  3.0  150.0
# ...    ...    ...    ...       ...         ...  ...    ...
# 9362   2.0      1      6   25000.0     48587.0  8.0  150.0
# 9369   3.0      1      7   35000.0     60000.0  9.0  220.0
# 9370   NaN      1     15  450000.0      3430.0  4.0  750.0
# 9371   8.0      1      7  139000.0     21300.0  4.0  400.0
# 9372   8.0      1      7   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 7 columns]

# %%
total_df.duplicated().sum()
# Out:
# np.int64(10)

# %%
total_df.drop_duplicates(inplace=True)

# %%
total_df
# Out:
#       city  owner  brand     price  kms_driven  age  power
# 0      1.0      1      1   35000.0     17654.0  3.0  110.0
# 1      2.0      1      2  119900.0     11000.0  4.0  350.0
# 2      2.0      1      3  600000.0       110.0  8.0  675.0
# 3      3.0      1      1   65000.0     16329.0  4.0  180.0
# 4      3.0      1      4   80000.0     10000.0  3.0  150.0
# ...    ...    ...    ...       ...         ...  ...    ...
# 9362   2.0      1      6   25000.0     48587.0  8.0  150.0
# 9369   3.0      1      7   35000.0     60000.0  9.0  220.0
# 9370   NaN      1     15  450000.0      3430.0  4.0  750.0
# 9371   8.0      1      7  139000.0     21300.0  4.0  400.0
# 9372   8.0      1      7   80000.0      7127.0  5.0  220.0
#
# [7314 rows x 7 columns]

# %%
#used_bike.csv file is encoded according to this method
total_df.to_csv("Used_bike.csv")

# %%
x=total_df.drop('age',axis=1)

# %%
x
# Out:
#       city  owner  brand     price  kms_driven  power
# 0      1.0      1      1   35000.0     17654.0  110.0
# 1      2.0      1      2  119900.0     11000.0  350.0
# 2      2.0      1      3  600000.0       110.0  675.0
# 3      3.0      1      1   65000.0     16329.0  180.0
# 4      3.0      1      4   80000.0     10000.0  150.0
# ...    ...    ...    ...       ...         ...    ...
# 9362   2.0      1      6   25000.0     48587.0  150.0
# 9369   3.0      1      7   35000.0     60000.0  220.0
# 9370   NaN      1     15  450000.0      3430.0  750.0
# 9371   8.0      1      7  139000.0     21300.0  400.0
# 9372   8.0      1      7   80000.0      7127.0  220.0
#
# [7314 rows x 6 columns]

# %%
y=total_df[['age']]

# %%
y
# Out:
#       age
# 0     3.0
# 1     4.0
# 2     8.0
# 3     4.0
# 4     3.0
# ...   ...
# 9362  8.0
# 9369  9.0
# 9370  4.0
# 9371  4.0
# 9372  5.0
#
# [7314 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import os
df=pd.read_csv('Used_Bikes.csv')

# %%
tvs_df=df[df['brand']=='TVS']

# %%
tvs_df
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
tvs_first_owner_df = tvs_df[tvs_df['owner']=='First Owner']

# %%
tvs_first_owner_df
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
royal_data=df[(df['brand']=='Royal Enfield')&
              (df['owner']=='First Owner')&
(df['kms_driven']<=50000)&
(df['age']<=2)&
(df['price']<=200000)]

# %%
royal_data
# Out:
#                                     bike_name     price          city  \
# 38          Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 139      Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 157      Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194               Royal Enfield Electra 350cc  145000.0     Bangalore
# 222      Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                       ...       ...           ...
# 7422  Royal Enfield Himalayan 410cc Sleet ABS  175000.0       Alipore
# 7559               Royal Enfield Bullet 500cc  170000.0         Delhi
# 8139    Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192      Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836    Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# 38        4550.0  First Owner  2.0  500.0  Royal Enfield
# ...

# %%
df.query("brand=='Royal Enfield'")
# Out:
#                                       bike_name     price  \
# 1                   Royal Enfield Classic 350cc  119900.0
# 8             Royal Enfield Thunderbird X 350cc  145000.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0
# 23           Royal Enfield Classic Chrome 500cc  121700.0
# 36                  Royal Enfield Classic 350cc   98800.0
# ...                                         ...       ...
# 32601               Royal Enfield Classic 350cc   95500.0
# 32614        Royal Enfield Bullet Electra 350cc  105000.0
# 32633               Royal Enfield Classic 350cc   87000.0
# 32634           Royal Enfield Thunderbird 350cc   70000.0
# 32639               Royal Enfield Classic 350cc   95500.0
#
#                       city  kms_driven         owner   age  power  \
# 1                    Delhi     11000.0   First Owner   4.0  350.0
# 8                Bangalore      9190.0   First Owner   3.0  350.0
# 9                    Delhi     19000.0  Second Owner   7.0  500.0
# ...

# %%
bike_data=df
